# %% [markdown]
#  ## Example 6: Double SE

# %%
import matplotlib.pyplot as plt
import sys
import numpy as np
import sympy as sp
import re

sys.path.append("../core/")
import BondGraph as bg

# %% [markdown]
# Example 6 image

# %%
model2 = bg.BondGraph(Name ='Serial 2 mass connection with 2 springs and one demper and ground connection + external force')

#Create some elements
SE_2 = bg.BGelement('SE', Position=[0,3])
SE_3 = bg.BGelement('SE', Position=[0,3])
SF_2 = bg.BGelement('SF', Position=[2,1])

C_2 = bg.BGelement('C', Position=[3,6])
C_3 = bg.BGelement('C', Position=[3,5])
R_2 = bg.BGelement('R', Position=[3,4])
I_2 = bg.BGelement('I', Position=[0,3])
I_3 = bg.BGelement('I', Position=[0,4])

OneJ_4 = bg.BGelement('1', Position=[0,1])
OneJ_5 = bg.BGelement('1', Position=[2,1])
OneJ_6 = bg.BGelement('1', Position=[2,0])
OneJ_7 = bg.BGelement('1', Position=[0,1])
OneJ_8 = bg.BGelement('1', Position=[1,1])


ZeroJ_2 = bg.BGelement('0', Position=[2,2])
ZeroJ_3 = bg.BGelement('0', Position=[4,2])

# Add the created elements to the model
model2.addElement(OneJ_4)
model2.addElement(OneJ_5)
model2.addElement(OneJ_6)
model2.addElement(OneJ_7)
model2.addElement(OneJ_8)

model2.addElement(ZeroJ_2)
model2.addElement(ZeroJ_3)

model2.addElement(C_2)
model2.addElement(C_3)
model2.addElement(R_2)
model2.addElement(I_2)
model2.addElement(I_3)
model2.addElement(SE_2)
model2.addElement(SF_2)

# add a connections between elements in model
model2.connect(SE_2, OneJ_4)
model2.connect(I_2, OneJ_4)
model2.connect(OneJ_4, ZeroJ_2)
model2.connect(ZeroJ_2, OneJ_5)
model2.connect(ZeroJ_2, OneJ_6)
model2.connect(C_2, OneJ_6)
model2.connect(R_2, OneJ_6)
model2.connect(OneJ_5, I_3)
model2.connect(OneJ_5, ZeroJ_3)
model2.connect(OneJ_7, ZeroJ_3)
model2.connect(C_3, OneJ_7)

model2.connect(OneJ_8, ZeroJ_3)
model2.connect(OneJ_8, SF_2)

# %%
# Set positions automatically for drawing (automatically done, but not ideally)
model2.render(layout_type='spring')
model2.draw()
# Out:
# WARNING 005: Some causality lost in drawings...
# WARNING 005: Some causality lost in drawings...
# WARNING 005: Some causality lost in drawings...
# WARNING 005: Some causality lost in drawings...
# WARNING 005: Some causality lost in drawings...
# WARNING 005: Some causality lost in drawings...
# WARNING 005: Some causality lost in drawings...
# WARNING 005: Some causality lost in drawings...
# WARNING 005: Some causality lost in drawings...
# WARNING 005: Some causality lost in drawings...
# WARNING 005: Some causality lost in drawings...
# WARNING 005: Some causality lost in drawings...
# WARNING 005: Some causality lost in drawings...

# %%
OneJ_8.setPosition([7,2])
OneJ_6.setPosition([0,2])
R_2.setPosition([-1,2])
C_2.setPosition([-1,3])
SE_2.setPosition([-1,-1])
C_3.setPosition([4,-1])
I_2.setPosition([1,0])
I_3.setPosition([0,4])

# %%
#we can get the position of element on the picture
OneJ_5.getPosition()
# Out:
# [-0.06524537836324404, 0.09917462653784823]

# %%
model2.applyRules()
# Out:
# NB! None val
# NB! None val
# NB! None val
# NB! None val
# NB! None val
# NB! None val
# NB! None val
# NB! None val
# NB! None val
# NB! None val
# NB! None val
# NB! None val
# NB! None val
# NB! None val
# NB! None val
# NB! None val
# NB! None val

# %%
model2.draw()

# %%
bg.show_ports_state(model2)
# Out:
# Element name:  1_7
# ++ port_id: 1 |  arrow:  Input |  causality:  Causal
# ++ port_id: 3 |  arrow:  Output |  causality:  Uncausal
# ++ port_id: 4 |  arrow:  Output |  causality:  Causal
# Element name:  1_8
# ++ port_id: 7 |  arrow:  Input |  causality:  Causal
# ++ port_id: 14 |  arrow:  Output |  causality:  Uncausal
# ++ port_id: 16 |  arrow:  Output |  causality:  Causal
# Element name:  1_9
# ++ port_id: 9 |  arrow:  Input |  causality:  Uncausal
# ++ port_id: 11 |  arrow:  Output |  causality:  Causal
# ++ port_id: 13 |  arrow:  Output |  causality:  Causal
# Element name:  1_10
# ++ port_id: 18 |  arrow:  Input |  causality:  Uncausal
# ++ port_id: 21 |  arrow:  Output |  causality:  Causal
# Element name:  1_11
# ++ port_id: 22 |  arrow:  Input |  causality:  Causal
# ++ port_id: 24 |  arrow:  Output |  causality:  Uncausal
# Element name:  0_12
# ++ port_id: 5 |  arrow:  Input |  causality:  Uncausal
# ++ port_id: 6 |  arrow:  Output |  causality:  Uncausal
# ++ port_id: 8 |  arrow:  Output |  causality:  Causal
# Element name:  0_13
# ++ port_id: 17 |  arrow:  Input |  causality:  Uncausal
# ++ port_id: 19 |  arrow:  Output |  causality:  Causal
# ++ port_id: 23 |  arrow:  Output |  causality:  Uncausal
# Element name:  C_2
# ++ port_id: 10 |  arrow:  Input |  causality:  Uncausal
# Element name:  C_3
# ++ port_id: 20 |  arrow:  Input |  causality:  Uncausal
# Element name:  R_4
# ++ port_id: 12 |  arrow:  Input |  causality:  Uncausal
# Element name:  I_5
# ++ port_id: 2 |  arrow:  Input |  causality:  Causal
# Element name:  I_6
# ++ port_id: 15 |  arrow:  Input |  causality:  Causal
# Element name:  SE_0
# ++ port_id: 0 |  arrow:  Output |  causality:  Uncausal
# Element name:  SF_1
# ++ port_id: 25 |  arrow:  Input |  causality:  Causal

# %%
model2.assign_equations()
equastions = model2.get_model_equations()

# %%
equastions
# Out:
# ['+e0=+SE0',
#  '+f0=+f1=+f2',
#  '+e1=+e0-e2',
#  '+f1=+1/I5*p5',
#  '+e2=+e3=+e4',
#  '+f0=+f1=+f2',
#  '+e3=+e7+e8',
#  '+f3=+f7=+f8',
#  '+e4=+e5+e6',
#  '+f4=+f2-f3',
#  '+e5=+1/C2*q2',
#  '+f4=+f5=+f6',
#  '+e6=+R4*f6',
#  '+f4=+f5=+f6',
#  '+e7=+e3-e8',
#  '+f7=+1/I6*p6',
#  '+e8=+e9=+e11',
#  '+f3=+f7=+f8',
#  '+e9=+e10',
#  '+f9=+f8-f11',
#  '+e10=+1/C3*q3',
#  '+f9=+f10',
#  '+e11=+e12',
#  '+f11=+f12',
#  '+e12=+e11',
#  '+f12=+SF1']

# %%
cauchy_state_equastions, variables_exp = model2.cauchy_form_equastions_sequence()
#just show
print("############## STATE EQUASIONS ############")
for i in cauchy_state_equastions.keys():
    print(i, '=', cauchy_state_equastions[i])
print("####################################################")
print(cauchy_state_equastions, model2.state_variables)
# Out:
# capacitor_variables= {'dq2/dt': f5, 'dq3/dt': f10, 'dp5/dt': e1, 'dp6/dt': e7}
# final_vars= [SE0, SF1, q2, q3, p5, p6, C2, C3, R4, I5, I6]
# dq2/dt =
# variables list = {f5}
# substituting... f5 -----b--- f4
# exp in progress... f4
# substituting... f4 -----b--- f2 - f3
# exp in progress... f2 - f3
# substituting... f3 -----b--- f7
# exp in progress... f2 - f7
# substituting... f2 -----b--- f0
# exp in progress... f0 - f7
# substituting... f7 -----b--- p6/I6
# exp in progress... f0 - p6/I6
# substituting... f0 -----b--- f1
# exp in progress... f1 - p6/I6
# substituting... f1 -----b--- p5/I5
# exp in progress... -p6/I6 + p5/I5
# -p6/I6 + p5/I5
# dq3/dt =
# variables list = {f10}
# substituting... f10 -----b--- f9
# exp in progress... f9
# substituting... f9 -----b--- -f11 + f8
# exp in progress... -f11 + f8
# substituting... f8 -----b--- f3
# exp in progress... -f11 + f3
# substituting... f11 -----b--- f12
# exp in progress... -f12 + f3
# substituting... f3 -----b--- f7
# exp in progress... -f12 + f7
# substituting... f12 -----b--- SF1
# exp in progress... -SF1 + f7
# substituting... f7 -----b--- p6/I6
# exp in progress... -SF1 + p6/I6
# -SF1 + p6/I6
# dp5/dt =
# variables list = {e1}
# substituting... e1 -----b--- e0 - e2
# exp in progress... e0 - e2
# substituting... e0 -----b--- SE0
# exp in progress... SE0 - e2
# substituting... e2 -----b--- e4
# exp in progress... SE0 - e4
# substituting... e4 -----b--- e5 + e6
# exp in progress... SE0 - e5 - e6
# substituting... e6 -----b--- R4*f6
# exp in progress... -R4*f6 + SE0 - e5
# substituting... e5 -----b--- q2/C2
# exp in progress... -R4*f6 + SE0 - q2/C2
# substituting... f6 -----b--- f4
# exp in progress... -R4*f4 + SE0 - q2/C2
# substituting... f4 -----b--- f2 - f3
# exp in progress... -R4*(f2 - f3) + SE0 - q2/C2
# substituting... f3 -----b--- f7
# exp in progress... -R4*(f2 - f7) + SE0 - q2/C2
# substituting... f2 -----b--- f0
# exp in progress... -R4*(f0 - f7) + SE0 - q2/C2
# substituting... f7 -----b--- p6/I6
# exp in progress... -R4*(f0 - p6/I6) + SE0 - q2/C2
# substituting... f0 -----b--- f1
# exp in progress... -R4*(f1 - p6/I6) + SE0 - q2/C2
# substituting... f1 -----b--- p5/I5
# exp in progress... -R4*(-p6/I6 + p5/I5) + SE0 - q2/C2
# -R4*(-p6/I6 + p5/I5) + SE0 - q2/C2
# dp6/dt =
# variables list = {e7}
# substituting... e7 -----b--- e3 - e8
# exp in progress... e3 - e8
# substituting... e3 -----b--- e2
# exp in progress... e2 - e8
# substituting... e8 -----b--- e9
# exp in progress... e2 - e9
# substituting... e2 -----b--- e4
# exp in progress... e4 - e9
# substituting... e9 -----b--- e10
# exp in progress... -e10 + e4
# substituting... e10 -----b--- q3/C3
# exp in progress... e4 - q3/C3
# substituting... e4 -----b--- e5 + e6
# exp in progress... e5 + e6 - q3/C3
# substituting... e6 -----b--- R4*f6
# exp in progress... R4*f6 + e5 - q3/C3
# substituting... e5 -----b--- q2/C2
# exp in progress... R4*f6 - q3/C3 + q2/C2
# substituting... f6 -----b--- f4
# exp in progress... R4*f4 - q3/C3 + q2/C2
# substituting... f4 -----b--- f2 - f3
# exp in progress... R4*(f2 - f3) - q3/C3 + q2/C2
# substituting... f3 -----b--- f7
# exp in progress... R4*(f2 - f7) - q3/C3 + q2/C2
# substituting... f2 -----b--- f0
# exp in progress... R4*(f0 - f7) - q3/C3 + q2/C2
# substituting... f7 -----b--- p6/I6
# exp in progress... R4*(f0 - p6/I6) - q3/C3 + q2/C2
# substituting... f0 -----b--- f1
# exp in progress... R4*(f1 - p6/I6) - q3/C3 + q2/C2
# substituting... f1 -----b--- p5/I5
# exp in progress... R4*(-p6/I6 + p5/I5) - q3/C3 + q2/C2
# R4*(-p6/I6 + p5/I5) - q3/C3 + q2/C2
# ############## STATE EQUASIONS ############
# dq2/dt = -p6/I6 + p5/I5
# dq3/dt = -SF1 + p6/I6
# dp5/dt = SE0 + R4*p6/I6 - R4*p5/I5 - q2/C2
# dp6/dt = -R4*p6/I6 + R4*p5/I5 - q3/C3 + q2/C2
# ####################################################
# {'dq2/dt': -p6/I6 + p5/I5, 'dq3/dt': -SF1 + p6/I6, 'dp5/dt': SE0 + R4*p6/I6 - R4*p5/I5 - q2/C2, 'dp6/dt': -R4*p6/I6 + R4*p5/I5 - q3/C3 + q2/C2} [q2, q3, p5, p6]

# %%
model2.make_state_statespace(cauchy_state_equastions)

# %%
model2.get_matrix_A()
# Out:
# Matrix([
# [    0,     0,   1/I5,  -1/I6],
# [    0,     0,      0,   1/I6],
# [-1/C2,     0, -R4/I5,  R4/I6],
# [ 1/C2, -1/C3,  R4/I5, -R4/I6]])

# %%
model2.get_matrix_B()
# Out:
# Matrix([
# [0,  0],
# [0, -1],
# [1,  0],
# [0,  0]])

# %% [markdown]
# ## DEBUG

# %%
# Enter for example 
cauchy_form_output_eq = model2.cauchy_form_output_eq(variables_exp, 'e7,f7')
model2.make_output_statespace(cauchy_form_output_eq)
# Out:
# Input the names of output variables:
# It mast be in list eff_flows:  [f8, f5, e2, f3, e7, f10, e3, e10, f1, e5, f9, f12, f11, f7, e1, f0, e12, e11, e4, e9, e6, f2, e8, f4, e0, f6] (Velocity of Force at some point)
# U entered this:  ['e7', 'f7']
# output variable=  e7
# first match [e3 - e8]
# next iteration with expression: e2 - e9
# next iteration with expression: -e10 + e4
# next iteration with expression: e5 + e6 - q3/C3
# next iteration with expression: R4*f6 - q3/C3 + q2/C2
# next iteration with expression: R4*f4 - q3/C3 + q2/C2
# next iteration with expression: R4*(f2 - f3) - q3/C3 + q2/C2
# next iteration with expression: R4*(f0 - f7) - q3/C3 + q2/C2
# next iteration with expression: R4*(f1 - p6/I6) - q3/C3 + q2/C2
# next iteration with expression: R4*(-p6/I6 + p5/I5) - q3/C3 + q2/C2
# output variable=  f7
# first match [p6/I6]

# %%
model2.get_matrix_C()
# Out:
# Matrix([
# [    0,     0,   1/I5,  -1/I6],
# [    0,     0,      0,   1/I6],
# [-1/C2,     0, -R4/I5,  R4/I6],
# [ 1/C2, -1/C3,  R4/I5, -R4/I6]])

# %%
model2.get_matrix_D()
# Out:
# Matrix([
# [0,  0],
# [0, -1],
# [1,  0],
# [0,  0]])

# %%
model2.state_variables
# Out:
# [q2, q3, p5, p6]

# %%
print('List of system parameters:', model2.parameter_variables)
parameters_list = model2.parameter_variables
# Out:
# List of system parameters: [C2, C3, R4, I5, I6]

# %%
parameters_values = [10, 2, 20, 30, 4]

# %%
# initial state
initial_state = np.zeros((len(model2.state_variables), 1))
print("initial_state: ", initial_state)
time_steps=400
sampling_period = 0.5
input_sequence = np.ones((time_steps, len(model2.input_variables)))
# print("input_sequence: ", input_sequence)
# Out:
# initial_state:  [[0.]
#  [0.]
#  [0.]
#  [0.]]

# %%
state, output = model2.simulate(initial_state, input_sequence, time_steps, sampling_period, parameters_values)     

plt.plot(output[0,:-1])
plt.plot(output[1,:-1])
plt.xlabel('Discrete time instant-k')
plt.ylabel('Position- d')
plt.title('System step response')
# Out:
# <class 'numpy.ndarray'> (4, 4) <class 'numpy.ndarray'> (4, 2)
# Text(0.5, 1.0, 'System step response')
